# %%
print("Hello, Tania!")
# Out:
# Hello, Tania!

# %%
import leaflet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import leaflet
#
# ModuleNotFoundError: No module named 'leaflet'

# %%
import leafmap

# %%
n = leafmap.Map()

# %%
n
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
n
# Out:
# Map(bottom=1882.0, center=[37.85750715625203, -98.78326696118762], controls=(ZoomControl(options=['position', …
